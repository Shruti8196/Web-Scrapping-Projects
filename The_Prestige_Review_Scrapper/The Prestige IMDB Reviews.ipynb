# %% [markdown]
# ## Scrapping The Prestige Reviews
#
# - Web Automation: Selenium
# - Scrapping Tags: Beautiful Soup
# - Language Used:  Python
#
#
# - Other Libraries:
#
#     - Python Time Module
#     - NLTK for analysis

# %%
# Importing Important libraries
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotVisibleException
import time


def download_reviews(soup):
        
        '''Input: soup- bs4.BeautifulSoup - Reviews Page
           
           This function downloads user reviews into reviews.txt file.
            '''
        # Fetching the reviews
        cnt=0
        for i in soup.findAll("div",class_="text show-more__control"):
            cnt+=1
            with open("reviews.txt","a",encoding='utf-8') as f:
                    f.write(i.text)
                    f.write("\n\n")

        print("Reviews were successfully downloaded in reviews.txt")

def get_reviews(url,filename):
    
    driver = webdriver.Chrome(executable_path=r"C:\Users\shrut\Downloads\chromedriver.exe")
    driver.get(url)

    while True:
        try:

    #       Getting the load more button id in imdb
            loadmore = driver.find_element_by_id("load-more-trigger")

    #       Wait until the toaster message disappears.
            time.sleep(2)
            loadmore.click()

    #       Wait until the toaster message disappears.
            time.sleep(2)
    

        except NoSuchElementException:

            print("Reached bottom of page")
            break

        except ElementNotVisibleException:
            
            print("Reached bottom of page")
            break
            
    soup = BeautifulSoup(driver.page_source,'html.parser')
    download_reviews(soup)

get_reviews("https://www.imdb.com/title/tt0482571/reviews","reviews.txt")
# Out:
# Reached bottom of page
# Reviews were successfully downloaded in reviews.txt

# %% [markdown]
# ### Reading the Reviews

# %%
# Reading the Reviews for basic analysis
with open("reviews.txt","r",encoding='utf-8') as f:
    r=f.read()
type(r)
# Out:
# str

# %% [markdown]
# ### What can we do with what we collected?
#
# Basic demonstration

# %%
import nltk
# nltk.download()

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from nltk.tokenize import RegexpTokenizer

 
# Fetching Stop Words
stop_words = set(stopwords.words('english')) 

tokenizer = RegexpTokenizer(r'\w+')
word_tokens=tokenizer.tokenize(r)

# Filtering the reviews to remove unnecessary stop words
filtered_words = [w for w in word_tokens if w.lower() not in stop_words]
print(filtered_words)
# Out:
# ['Great', 'movie', 'Great', 'actors', 'writers', 'twists', 'Something', 'see', 'anybody', 'said', 'rivalry', 'two', 'magicians', 'reference', 'Tesla', 'Edison', 'rivalry', 'beginning', 'worked', 'together', 'became', 'opponents', 'think', 'Borden', 'Tesla', 'cause', 'always', 'talented', 'Angier', 'Edison', 'stole', 'Borden', 'idea', 'Surely', 'best', 'movies', 'century', 'sure', 'watch', 'one', 'time', 'Prestige', 'adapted', 'award', 'winning', 'novel', 'name', 'Christopher', 'Priest', 'intricate', 'tale', 'passion', 'intrigue', 'deceit', 'obsession', 'two', 'illusionists', 'whose', 'morbid', 'covetousness', 'absolute', 'supremacy', 'profession', 'engenders', 'fierce', 'rivalry', 'turns', 'internecine', 'ultimately', 'consumes', 'Alfred', 'Borden', 'Christian', 'Bale', 'Robert', 'Angier', 'Hugh', 'Jackman', 'start', 'careers', 'highly', 'ambitious', 'young', 'men', 'assisting', 'elderly', 'illusionist', 'named', 'Milton', 'Borden', 'incessant', 'longing', 'innovation', 'leads', 'accidental', 'death', 'Angier', 'wife', 'Borden', 'marries', 'Sarah', 'apparent', 'happiness', 'aggravates', 'sense', 'revulsion', 'Angier', 'heart', 'Angier', 'vindictive', 'intervention', 'bullet', 'catch', 'trick', 'causes', 'Borden', 'lose', 'two', 'fingers', 'Though', 'events', 'sowed', 'seeds', 'implacable', 'hatred', 'unremitting', 'yearning', 'perpetually', 'insatiable', 'egos', 'outperform', 'eventually', 'drives', 'perdition', 'Angier', 'starts', 'performing', 'sobriquet', 'Great', 'Danton', 'Cutter', 'Michael', 'Caine', 'illusion', 'engineer', 'Borden', 'stage', 'name', 'Professor', 'Fellon', 'engineer', 'Angier', 'adept', 'showman', 'lacks', 'technical', 'prowess', 'contrary', 'Borden', 'highly', 'skillful', 'lacks', 'taste', 'grandeur', 'showmanship', 'regards', 'obstacle', 'owing', 'bitterly', 'intertwined', 'past', 'starts', 'series', 'events', 'tries', 'stymie', 'means', 'possible', 'sabotage', 'abduction', 'incrimination', 'even', 'killings', 'Awed', 'apparent', 'genuineness', 'Borden', 'version', 'Transported', 'Man', 'inveigled', 'Borden', 'deliberate', 'misdirection', 'Angier', 'travels', 'miles', 'spends', 'fortune', 'approach', 'ingenious', 'scientist', 'named', 'Nikola', 'Tesla', 'David', 'Bowie', 'order', 'cajole', 'building', 'machine', 'machine', 'could', 'help', 'outperform', 'Borden', 'Nikola', 'Tesla', 'apostle', 'Alternating', 'Current', 'rightly', 'thinks', 'superior', 'Direct', 'Current', 'immense', 'pressure', 'imparted', 'Thomas', 'Edison', 'ruthless', 'advocator', 'Direct', 'Current', 'men', 'Tesla', 'Edison', 'men', 'close', 'Tesla', 'runs', 'time', 'hence', 'funds', 'research', 'forced', 'oblige', 'Angier', 'last', 'client', 'Tesla', 'flees', 'scene', 'shortly', 'fulfilling', 'promise', 'Angier', 'without', 'leaving', 'strong', 'note', 'caution', 'use', 'invention', 'whose', 'ever', 'increasing', 'skepticism', 'Tesla', 'placated', 'efficacy', 'masterful', 'invention', 'Using', 'Tesla', 'machine', 'Angier', 'introduces', 'version', 'Transported', 'Man', 'becomes', 'instant', 'success', 'lieu', 'terrible', 'self', 'sacrifice', 'Angier', 'make', 'every', 'night', 'performing', 'story', 'culminates', 'viewer', 'startled', 'many', 'revelations', 'including', 'mental', 'physical', 'torments', 'Borden', 'complex', 'character', 'undergoes', 'owing', 'total', 'devotion', 'towards', 'art', 'success', 'act', 'illusion', 'solely', 'depends', 'upon', 'deftness', 'three', 'parts', 'viz', 'Pledge', 'Turn', 'Prestige', 'performed', 'Similarly', 'movie', 'success', 'three', 'main', 'aspects', 'e', 'screenplay', 'direction', 'acting', 'ought', 'top', 'notch', 'Christopher', 'Nolan', 'incredibly', 'manages', 'strike', 'right', 'cords', 'Prestige', 'riveting', 'maneuvers', 'coupled', 'ingenious', 'auteur', 'skills', 'aggrandize', 'brilliance', 'movie', 'ten', 'fold', 'Nolan', 'succeeds', 'dream', 'assemblage', 'actors', 'almost', 'everyone', 'giving', 'memorable', 'performance', 'Christian', 'Bale', 'Hugh', 'Jackman', 'superb', 'lead' ...

# %%
from nltk.probability import FreqDist
fdist = FreqDist(filtered_words)
print(fdist)
# Out:
# <FreqDist with 10985 samples and 95735 outcomes>

# %% [markdown]
# **The most common keywords includes magic, trick, good and of that ilk. It was obvious as the movie does revolve around two magicians Borden and Angier. One the word is Nolan who is the director of the film. Nolan was mentioned a lot in many reviews, next we get lines that has Nolan in it.**

# %%
# Getting the most common 15 words
fdist.most_common(15)
# Out:
# [('movie', 2171),
#  ('film', 1376),
#  ('one', 957),
#  ('Nolan', 722),
#  ('Borden', 639),
#  ('Angier', 630),
#  ('Jackman', 623),
#  ('Bale', 609),
#  ('story', 576),
#  ('magic', 575),
#  ('time', 566),
#  ('like', 532),
#  ('trick', 500),
#  ('good', 500),
#  ('Prestige', 489)]

# %%
t = nltk.tokenize.WhitespaceTokenizer()  # or any other Tokenizer
c = nltk.Text(t.tokenize(r))

# %%
# finding instances that had movie word in it
for i in c.concordance_list(u"movie"):
    print(i.line,"\n")
# Out:
# Great movie with Great actors writers and twists
#
# tige are performed. Similarly, for a movie to be a success, its three main aspe
#
# lls aggrandize the brilliance of the movie ten-fold. Nolan succeeds in having a
#
# yal as Borden's paramour, Olivia.The movie is a roller-coaster of a ride with i
#
# sy, is truly exemplary and makes the movie a contemporary classic. The movie is
#
# he movie a contemporary classic. The movie is a tapestry of twists and turns, w
#
# scussed it all the way home from the movie theater. This is a winner and should
#
# better plot. I highly recommend this movie to all ages.New idea for a movie, an
#
#  a magician on TV!i had to give this movie a 10/10, and i only have 4 movies th
#
# it as much as i did. What makes this movie so incredible is that while it is in
#
# redible is that while it is indeed a movie about magicians (or illusionists) it
#
# ly stays with you. This was the best movie I have seen in at least the past two
#
#  spent doing better things. Yet this movie was truly a masterpiece and kept me
#
#  twist the writer planned. With this movie I was still left wondering into the
#
# thing but Christopher Nolan made the movie and that's the bottom line! The fina
#
# ative so flawlessly. What makes this movie so incredible is that while it is in
#
# redible is that while it is indeed a movie about magicians (or illusionists) it
#
#  but that is all. Overall: 9/10 This movie was truly a game-changer for me. I i
#
# I think you'll be glad you did. This movie is beyond brilliant. I never payed t
#
# was so incredibly disappointing. The movie takes place in the 19th century. Her
#
# t fatal flaw (except the rest of the movie wasn't that great either). There's a
#
#  the kind of ambiguous, almost-moral movie that makes you just cringe with the
#
# sn't need any of those tricks. Great movie and best movie I've seen directed by
#
# f those tricks. Great movie and best movie I've seen directed by Christopher No
#
#  Christopher Nolan. The story of the movie was great and I did not expect the e

# %%
# Getting lines where nolan was mentioned
for i in c.concordance_list(u"Nolan"):
    print(i.line,"\n")
# Out:
# e ought to be top-notch. Christopher Nolan incredibly manages to strike all the
#
# he brilliance of the movie ten-fold. Nolan succeeds in having a dream assemblag
#
# ate masterpiece. The uncanny feat of Nolan to manifest a motion picture, which
#
# ection, but if you're willing to let Nolan lead you on the journey into increas
#
# eed to know anything but Christopher Nolan made the movie and that's the bottom
#
# I was floored by the deftness of how Nolan weaved and juxtaposed the non linear
#
#  Prestige is directed by Christopher Nolan and stars Hugh Jackman and Christian
#
# ovie. One of Nolan's best yet again. Nolan is such an inspiration, he hasn't ma
#
# e writing in this film is excellent. Nolan brought the script to life with thes
#
# s/CGI to wow the viewers Christopher Nolan is an unmitigated genius and doesn't
#
# l have been a statue, and apparently Nolan never told Caine that he wasn't stil
#
# t just doesn't get any better. chris nolan you are a god. As a fan of old Twili
#
# uctures have become more acceptable. Nolan has earned a place as one of the bes
#
# finitely be one of them.10/10 I love nolan movies it just give you the differen
#
# vals. Likewise, director Christopher Nolan keeps all of his balls in the air, t
#
#  or he'd be back to give Christopher Nolan a piece of his mind. Sadly not a jok
#
# es ever if not the best..Christopher Nolan is a genius..there is no flaw in the
#
# l acted. That having been said Chris Nolan plants so many winks toward the audi
#
# on. However, as with all christopher Nolan movies, the movie is paced very well
#
# ll have to look into it. Christopher Nolan is an undeniably great filmmaker and
#
# ce. The supporting cast all deliver, Nolan still can't write women, Bowie, Cain
#
# kis pick up the slack easily. Whilst Nolan has become much more of a High conce
#
# ws the brilliant storytelling, which Nolan has mastered. I almost gave this fil
#
# its weight. I have seen almost every Nolan film, except Memento, Dunkirk, and T
#
# , though other reviewers have stated Nolan structures the film where there is n
