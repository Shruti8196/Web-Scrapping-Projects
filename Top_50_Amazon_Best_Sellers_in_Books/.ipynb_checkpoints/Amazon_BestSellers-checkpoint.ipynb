# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import numpy as np
import pandas as pd

site= "https://www.amazon.in/gp/bestsellers/books"
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site,headers=hdr)
page = urlopen(req)
soup = BeautifulSoup(page)

# %%
rank=[];name=[];price=[];rating=[]
num_ratings=[]
for i in soup.find_all("div",class_="a-section a-spacing-none aok-relative"):
  
          rank.append(int(i.find("span",class_="zg-badge-text").string[1:]))
          name.append(i.find("img",alt=True)['alt'])
          price.append(i.find("span",class_="p13n-sc-price").text)
          r= i.find("span",class_="a-icon-alt" )
          n_r=i.find("a",class_="a-size-small a-link-normal")
          if n_r==None:
            num_ratings.append(n_r)
          else:
            num_ratings.append(int(i.find("a",class_="a-size-small a-link-normal").text.replace(',','')))
          if r==None:
            rating.append(r)
          else:
            rating.append(r.text[:4])

# %%
print(len(rank))
print(len(name))
print(len(price))
print(len(rating))
print(len(num_ratings))
# Out:
# 50
# 50
# 50
# 50
# 50

# %%
Top_50_BestSellers=pd.DataFrame({
    "Rank":rank,
    "Book Title":name,
    "Price":price,
    "Rating":rating,
    "#Num of Ratings":num_ratings

})
Top_50_BestSellers.set_index("Rank",inplace=True)

path=input("Enter Path-")
Top_50_BestSellers.to_excel(path+"Top_50_BestSellers.xlsx")
print("Update Successful")
# Out:
#                                              Book Title       Price Rating  \
# Rank
# 1                               The Psychology of Money    ₹ 290.00   4.5
# 2     My First Library: Boxset of 10 Board Books for...    ₹ 399.00   4.5
# 3     Ikigai: The Japanese secret to a long and happ...    ₹ 379.00   4.6
# 4     Grandma's Bag of Stories: Collection of 20+ Il...    ₹ 191.00   4.6
# 5     My First Book of Patterns Pencil Control: Patt...     ₹ 89.00   4.4
# 6     Indian Polity - For Civil Services and Other S...    ₹ 585.00   4.6
# 7     World’s Greatest Books For Personal Growth & W...    ₹ 299.00   4.5
# 8     Educart All Subjects Final Revision Book Of CB...    ₹ 248.00   4.4
# 9                                         The Alchemist    ₹ 175.00   4.6
# 10    26 Years UPSC IAS/ IPS Prelims Topic-wise Solv...    ₹ 318.00   4.5
# 11           Very First Sight Words Sentences Level - 1    ₹ 108.00   4.5
# 12    Atomic Habits: The life-changing million copy ...    ₹ 445.00   4.6
# 13    Rich Dad Poor Dad: What the Rich Teach Their K...    ₹ 383.00   4.6
# 14    Mathematics for Class 9 by R D Sharma (Examina...    ₹ 380.00   4.6
# 15                  The Power of Your Subconscious Mind    ₹ 109.00   4.5
# 16    Writing Practice Boxset: Pack of 4 Books (Writ...    ₹ 159.00   4.4
# 17    Quantitative Aptitude for Competitive Examinat...    ₹ 435.00   4.4
# 18    Combo Pack: Lakhmir Singh Class 10 Science (Bi...  ₹ 1,198.00   4.4
# 19                                    General Knowledge    ₹ 158.00   4.4
# 20    The Intelligent Investor (English) Paperback –...    ₹ 450.00   4.5
# 21                                 Word Power Made Easy     ₹ 91.00   4.4
# 22    Life's Amazing Secrets: How to Find Balance an...    ₹ 217.00   4.6
# 23    Picture Books Collection for Early Learning (S...    ₹ 235.00   4.3
# 24    101 Panchatantra Stories for Children: Colourf...    ₹ 135.00   4.5
# 25       Oxford Student Atlas for India - Third Edition    ₹ 210.00   4.6
# 26                                  One Arranged Murder    ₹ 150.00   4.3
# 27    T.S. Grewal's Double Entry Book Keeping: Accou...    ₹ 464.00   4.6
# 28                                 Word Power Made Easy     ₹ 95.00   4.4
# 29    Wren & Martin High School English Grammar and ...    ₹ 236.00   4.4
# 30                           The Richest Man in Babylon     ₹ 99.00   4.4
# 31    Mathematics for Class 10 by R D Sharma (Examin...    ₹ 494.00   4.6
# 32          Lines and Curves (Pattern Writing) - Part 1     ₹ 60.00   4.4
# 33    My First 1000 Words: Early Learning Picture Bo...    ₹ 149.00   4.4
# 34                Sapiens: A Brief History of Humankind    ₹ 377.00   4.7
# 35    Karma: A Yogi's Guide to Crafting Your Destiny...    ₹ 259.00   None
# 36                           Great Stories for Children    ₹ 148.00   4.5
# 37    NCERT Textbooks in English for class 12 - Flam...     ₹ 89.00   4.6
# 38    The Magic of the Lost Temple: Illustrated, eas...    ₹ 133.00   4.7
# 39                                 1001 Activities Book    ₹ 240.00   4.5
# 40                        The Monk Who Sold His Ferrari    ₹ 153.00   4.5
# 41    Attitude Is Everything: Change Your Attitude ....    ₹ 161.00   4.5
# 42    Refreshing Mandala - Colouring Book for Adults...    ₹ 150.00   4.6
# 43    101 Brain Booster Activity Book: Fun Activity ...    ₹ 129.00   4.4
# 44    Objective NCERT at your FINGERTIPS for NEET-AI...    ₹ 561.00   4.6
# 45    Think Like a Monk: The secret of how to harnes...    ₹ 340.00   4.7
# 46    Brain Games for Clever Kids: Puzzles to Exerci...    ₹ 199.00   4.3
# 47    Computer Science with Python Textbook and Prac...    ₹ 595.00   4.5
# 48                       Spoken English Course (Telugu)    ₹ 399.00   4.4
# 49    The 5 AM Club: Own Your Morning, Elevate Your ...    ₹ 220.00   4.4
# 50             Harry Potter and the Philosopher's Stone    ₹ 299.00   4.7
#
#       #Num of Ratings
# Rank
# 1              7344.0
# 2             19620.0
# 3             12003.0
# 4              4360.0
# 5              4287.0
# 6              7196.0
# 7              4814.0
# 8               141.0
# 9             49154.0
# 10             1199.0
# 11             2517.0
# 12            16743.0
# 13            38115.0
# 14              724.0
# 15            28514.0
# 16             2102.0
# 17            10123.0
# 18              397.0
# 19             9889.0
# 20            21419.0
# 21            18663.0
# 22             6629.0
# 23             5073.0
# 24              697.0
# 25             4472.0
# 26             7439.0
# 27               28.0
# 28            18663.0
# 29             3714.0
# 30            16371.0
# 31             1094.0
# 32             2231.0
# 33             1686.0
# 34            30857.0
# 35                NaN
# 36             3594.0
# 37              243.0
# 38             2041.0
# 39             3551.0
# 40            12134.0
# 41             7766.0
# 42             2948.0
# 43              806.0
# 44             1037.0
# 45            11530.0
# 46             4198.0
# 47              521.0
# 48              990.0
# 49            10742.0
# 50            25172.0

# %%
Top_50_BestSellers.to_excel("Top_50_BestSellers.xlsx")

# %%
Top_50_BestSellers.sort_values(by="#Num of Ratings",axis=0,ascending=False)
# Out:
#                                              Book Title       Price Rating  \
# Rank
# 9                                         The Alchemist    ₹ 175.00   4.6
# 13    Rich Dad Poor Dad: What the Rich Teach Their K...    ₹ 383.00   4.6
# 34                Sapiens: A Brief History of Humankind    ₹ 377.00   4.7
# 15                  The Power of Your Subconscious Mind    ₹ 109.00   4.5
# 50             Harry Potter and the Philosopher's Stone    ₹ 299.00   4.7
# 20    The Intelligent Investor (English) Paperback –...    ₹ 450.00   4.5
# 2     My First Library: Boxset of 10 Board Books for...    ₹ 399.00   4.5
# 28                                 Word Power Made Easy     ₹ 95.00   4.4
# 21                                 Word Power Made Easy     ₹ 91.00   4.4
# 12    Atomic Habits: The life-changing million copy ...    ₹ 445.00   4.6
# 30                           The Richest Man in Babylon     ₹ 99.00   4.4
# 40                        The Monk Who Sold His Ferrari    ₹ 153.00   4.5
# 3     Ikigai: The Japanese secret to a long and happ...    ₹ 379.00   4.6
# 45    Think Like a Monk: The secret of how to harnes...    ₹ 340.00   4.7
# 49    The 5 AM Club: Own Your Morning, Elevate Your ...    ₹ 220.00   4.4
# 17    Quantitative Aptitude for Competitive Examinat...    ₹ 435.00   4.4
# 19                                    General Knowledge    ₹ 158.00   4.4
# 41    Attitude Is Everything: Change Your Attitude ....    ₹ 161.00   4.5
# 26                                  One Arranged Murder    ₹ 150.00   4.3
# 1                               The Psychology of Money    ₹ 290.00   4.5
# 6     Indian Polity - For Civil Services and Other S...    ₹ 585.00   4.6
# 22    Life's Amazing Secrets: How to Find Balance an...    ₹ 217.00   4.6
# 23    Picture Books Collection for Early Learning (S...    ₹ 235.00   4.3
# 7     World’s Greatest Books For Personal Growth & W...    ₹ 299.00   4.5
# 25       Oxford Student Atlas for India - Third Edition    ₹ 210.00   4.6
# 4     Grandma's Bag of Stories: Collection of 20+ Il...    ₹ 191.00   4.6
# 5     My First Book of Patterns Pencil Control: Patt...     ₹ 89.00   4.4
# 46    Brain Games for Clever Kids: Puzzles to Exerci...    ₹ 199.00   4.3
# 29    Wren & Martin High School English Grammar and ...    ₹ 236.00   4.4
# 36                           Great Stories for Children    ₹ 148.00   4.5
# 39                                 1001 Activities Book    ₹ 240.00   4.5
# 42    Refreshing Mandala - Colouring Book for Adults...    ₹ 150.00   4.6
# 11           Very First Sight Words Sentences Level - 1    ₹ 108.00   4.5
# 32          Lines and Curves (Pattern Writing) - Part 1     ₹ 60.00   4.4
# 16    Writing Practice Boxset: Pack of 4 Books (Writ...    ₹ 159.00   4.4
# 38    The Magic of the Lost Temple: Illustrated, eas...    ₹ 133.00   4.7
# 33    My First 1000 Words: Early Learning Picture Bo...    ₹ 149.00   4.4
# 10    26 Years UPSC IAS/ IPS Prelims Topic-wise Solv...    ₹ 318.00   4.5
# 31    Mathematics for Class 10 by R D Sharma (Examin...    ₹ 494.00   4.6
# 44    Objective NCERT at your FINGERTIPS for NEET-AI...    ₹ 561.00   4.6
# 48                       Spoken English Course (Telugu)    ₹ 399.00   4.4
# 43    101 Brain Booster Activity Book: Fun Activity ...    ₹ 129.00   4.4
# 14    Mathematics for Class 9 by R D Sharma (Examina...    ₹ 380.00   4.6
# 24    101 Panchatantra Stories for Children: Colourf...    ₹ 135.00   4.5
# 47    Computer Science with Python Textbook and Prac...    ₹ 595.00   4.5
# 18    Combo Pack: Lakhmir Singh Class 10 Science (Bi...  ₹ 1,198.00   4.4
# 37    NCERT Textbooks in English for class 12 - Flam...     ₹ 89.00   4.6
# 8     Educart All Subjects Final Revision Book Of CB...    ₹ 248.00   4.4
# 27    T.S. Grewal's Double Entry Book Keeping: Accou...    ₹ 464.00   4.6
# 35    Karma: A Yogi's Guide to Crafting Your Destiny...    ₹ 259.00   None
#
#       #Num of Ratings
# Rank
# 9             49154.0
# 13            38115.0
# 34            30857.0
# 15            28514.0
# 50            25172.0
# 20            21419.0
# 2             19620.0
# 28            18663.0
# 21            18663.0
# 12            16743.0
# 30            16371.0
# 40            12134.0
# 3             12003.0
# 45            11530.0
# 49            10742.0
# 17            10123.0
# 19             9889.0
# 41             7766.0
# 26             7439.0
# 1              7344.0
# 6              7196.0
# 22             6629.0
# 23             5073.0
# 7              4814.0
# 25             4472.0
# 4              4360.0
# 5              4287.0
# 46             4198.0
# 29             3714.0
# 36             3594.0
# 39             3551.0
# 42             2948.0
# 11             2517.0
# 32             2231.0
# 16             2102.0
# 38             2041.0
# 33             1686.0
# 10             1199.0
# 31             1094.0
# 44             1037.0
# 48              990.0
# 43              806.0
# 14              724.0
# 24              697.0
# 47              521.0
# 18              397.0
# 37              243.0
# 8               141.0
# 27               28.0
# 35                NaN

# %%
# %run Web_Scraping_BestSellers.py
# Out:
# C:\Users\shrut\Data Analytics Portfolio\Web_Scrapping_Projects\Top 50 Amazon Best Sellers in Books\Web_Scraping_BestSellers.py:14: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 14 of the file C:\Users\shrut\Data Analytics Portfolio\Web_Scrapping_Projects\Top 50 Amazon Best Sellers in Books\Web_Scraping_BestSellers.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(page)
# Enter Path-C:\Users\shrut\Data Analytics Portfolio\Web_Scrapping_Projects\Top 50 Amazon Best Sellers in Books\
# Update Successful
